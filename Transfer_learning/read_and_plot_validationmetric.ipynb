# %% [markdown]
# by: @leopauly

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 25})
plt.rcParams["font.family"] = "serif"
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams["figure.figsize"] = [10, 10]

with open("C3D_MIME20_train_90_10_shuffle_storing_accuracies.txt") as f:
    data = f.read()

data = data.split('\n')
data=data[0:len(data)-1]

print('UCF101 accuraccies', [(row) for row in data])
y = [float(row) for row in data]
x = range(0, len(y))


#plt.title("Validation accuracy during training")    
plt.xlabel('Epoches')
plt.ylabel('Accuracy (%) ')
plt.plot(x,y, c='brown', linewidth=3, label='MIME dataset')


with open("2.C3D_ucf_model_training_multigpu_py_k80_1_storing_accuracies.txt") as f:
    data = f.read()
data = data.split('\n')
data=data[0:len(data)-1]

print('UCF101 accuraccies', [(row) for row in data])
y = [float(row) for row in data]
x = range(0, len(y))

plt.plot(x,y, c='green', linewidth=3, label='UCF101 dataset')
plt.legend()

plt.show()
# Out:
# UCF101 accuraccies ['11.7822966507', '14.8624401914', '20.6937799043', '26.7045454545', '34.3899521531', '38.6662679426', '44.9162679426', '48.8935406699', '53.1698564593', '56.5490430622', '59.1507177033', '60.9748803828', '63.7858851675', '65.490430622', '68.0622009569', '68.8696172249', '70.7535885167', '71.3217703349', '72.3086124402', '74.043062201', '75.4784688995', '75.269138756', '76.764354067', '76.5251196172', '77.0933014354', '77.8110047847', '78.0502392344', '78.528708134', '78.9772727273', '79.0071770335', '79.6650717703', '80.8911483254', '79.8744019139', '80.9210526316', '80.5322966507', '81.0107655502', '82.1770334928', '81.788277512', '81.3397129187', '81.9377990431', '82.3265550239', '82.6255980861', '82.7153110048', '82.4461722488', '83.0442583732', '82.9246411483', '82.9246411483', '83.2535885167', '83.3433014354', '83.2236842105', '83.5227272727', '84.240430622', '83.6722488038', '83.6423444976', '84.0610047847', '84.6291866029', '83.971291866', '84.4497607656', 
# ...

# %%
with open("2.C3D_ucf_model_training_multigpu_py_k80_1_storing_accuracies.txt") as f:
    data = f.read()
data = data.split('\n')
data=data[0:len(data)-1]

print('UCF101 accuraccies', [(row) for row in data])
y = [float(row) for row in data]
x = range(0, len(y))

#plt.title("Validation accuracy during training")    
plt.xlabel('Epoches')
plt.ylabel('Accuracy (%) ')
plt.plot(x,y, c='green', linewidth=3, label='UCF101 dataset')
#plt.legend()

plt.show()
# Out:
# UCF101 accuraccies ['1.72101449275', '1.84178743961', '2.50603864734', '2.80797101449', '3.92512077295', '5.25362318841', '7.0652173913', '8.30314009662', '10.0241545894', '11.6847826087', '13.3152173913', '15.7910628019', '16.4553140097', '19.4746376812', '19.9879227053', '22.7355072464', '23.520531401', '24.8792270531', '26.6304347826', '28.1400966184', '28.6231884058', '31.038647343', '31.7934782609', '33.5446859903', '34.5410628019', '36.8357487923', '36.5942028986', '38.8285024155', '39.4927536232', '40.7910628019', '42.4214975845', '43.1763285024', '44.806763285', '45.8031400966', '46.7391304348', '47.9468599034', '49.6074879227', '49.4867149758', '49.9396135266', '51.6304347826', '51.5700483092', '52.9891304348', '53.4722222222', '53.8949275362', '54.4082125604', '54.0458937198', '55.3442028986', '54.4384057971', '55.9480676329', '55.5555555556', '56.0688405797', '56.7330917874', '56.5519323671', '57.0652173913', '56.884057971', '57.5785024155', '57.3369565217', '57.4879227053
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 25})
plt.rcParams["font.family"] = "serif"
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams["figure.figsize"] = [10, 10]

#---------------------------------------------------------------------------------------#-

with open("C3D_MIME20_train_90_10_shuffle_storing_accuracies.txt") as f:
    data = f.read()

data = data.split('\n')
data=data[0:len(data)-1]

print('MIME accuraccies', [(row) for row in data])
y = [float(row) for row in data]
x = range(0, len(y))


#plt.title("Validation accuracy during training")    
plt.xlabel('Epoches')
plt.ylabel('Accuracy (%) ')
plt.plot(x,y, c='brown', linewidth=3, label='MIME dataset')
plt.legend()
plt.show()

#---------------------------------------------------------------------------------------#-
# Out:
# UCF101 accuraccies ['11.7822966507', '14.8624401914', '20.6937799043', '26.7045454545', '34.3899521531', '38.6662679426', '44.9162679426', '48.8935406699', '53.1698564593', '56.5490430622', '59.1507177033', '60.9748803828', '63.7858851675', '65.490430622', '68.0622009569', '68.8696172249', '70.7535885167', '71.3217703349', '72.3086124402', '74.043062201', '75.4784688995', '75.269138756', '76.764354067', '76.5251196172', '77.0933014354', '77.8110047847', '78.0502392344', '78.528708134', '78.9772727273', '79.0071770335', '79.6650717703', '80.8911483254', '79.8744019139', '80.9210526316', '80.5322966507', '81.0107655502', '82.1770334928', '81.788277512', '81.3397129187', '81.9377990431', '82.3265550239', '82.6255980861', '82.7153110048', '82.4461722488', '83.0442583732', '82.9246411483', '82.9246411483', '83.2535885167', '83.3433014354', '83.2236842105', '83.5227272727', '84.240430622', '83.6722488038', '83.6423444976', '84.0610047847', '84.6291866029', '83.971291866', '84.4497607656', 
# ...
